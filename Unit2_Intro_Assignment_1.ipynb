# %% [markdown]
# <a href="https://colab.research.google.com/github/VazKBCC22/cuny_lagcc_micro_credential_data_analytics/blob/main/Unit2_Intro_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 1 - Intrdouction to Python - Assignment 1
#
# > Indented block

# %% [markdown]
# ## 1.	What is Python and why is it useful?

# %% [markdown]
# ## 2.	Are the following variable names allowed in python?

# %% [markdown]
# a.	1_message
#
# b.	Greeting_message
#
# c.	Message_1
#
# d.	First name
#
# e.	Full_name

# %% [markdown]
# d. First name is not allowed in Python because of the space and a 1_message is not allowed because in Python a variable cannot start with a number.

# %% [markdown]
# ## 3.	Create a variable that holds the string “hello there!”

# %%
greeting = "hello there!"

# %% [markdown]
# ## 4.	Create a variable for first name, last name and an email extension.  Concatenating all three together to form an email address.  For example: firstnamelastname@gmail.com

# %%
first = "hot"
last = "babe"
add = "@gmail.com"
email = first + last + add
print(email)
# Out:
# hotbabe@gmail.com

# %% [markdown]
# ## 5.	Store someone you know name in a variable called name.  Print their name in lower and uppercase using a method.

# %%
name = 'Isabelle'
small_cap = name.lower()
large_cap = name.upper()
print(small_cap)
print(large_cap)
# Out:
# isabelle
# ISABELLE
